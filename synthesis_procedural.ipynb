# %% [markdown]
# <a href="https://colab.research.google.com/github/PaweekornS/underwater_sonar/blob/main/synthesis_procedural.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
import os
import random
from PIL import Image
import numpy as np

# --- 0. ติดตั้ง NumPy (รันแค่ครั้งเดียวใน Colab) ---
try:
    import numpy as np
except ImportError:
    print("NumPy is not installed. Installing now...")
    # !pip install numpy
    import numpy as np

# --- 1. Define Paths (ใช้ SeniorProj) ---
BACKGROUND_DIR = '/content/drive/MyDrive/SeniorProj/backgrounds'
OBJECT_DIR = '/content/drive/MyDrive/SeniorProj/objects'
OUTPUT_DIR = '/content/drive/MyDrive/SeniorProj/output'

# --- 2. Parameters Setup ---
NUM_OBJECTS_PER_BG = 1
MIN_SCALE_FACTOR = 0.05
MAX_SCALE_FACTOR = 0.15

# ค่าสีที่ถือว่าเป็น Object และ Shadow
OBJECT_COLOR = 255
SHADOW_COLOR = 0

# ช่วงความคลาดเคลื่อนที่ยอมรับได้สำหรับสีขาว/ดำ (Object/Shadow)
ACTIVE_COLOR_TOLERANCE = 5

# >>>>>> ปรับค่าความเข้ม (Strength) ตรงนี้ <<<<<<
# ค่าเดิม: LIGHTEN_STRENGTH = 0.25, DARKEN_STRENGTH = 0.35
LIGHTEN_STRENGTH = 0.5   # เพิ่มความสว่างของ Object ขึ้น 2 เท่า (จาก 0.25)
DARKEN_STRENGTH = 0.7    # เพิ่มความมืดของ Shadow ขึ้น 2 เท่า (จาก 0.35)


# --- 3. Core Function ---

def process_images_colorize_and_blend_increased_strength():
    print("--- Starting Colorize and Blend Process (Increased Strength) ---")

    # Mount Drive
    from google.colab import drive
    try:
        drive.mount('/content/drive', force_remount=True)
    except:
        print("!! Could not mount Google Drive. Please check connection.")
        return

    # สร้างโฟลเดอร์ Output
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    # ดึงรายชื่อไฟล์
    try:
        background_files = [f for f in os.listdir(BACKGROUND_DIR) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
        object_files = [f for f in os.listdir(OBJECT_DIR) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    except FileNotFoundError as e:
        print(f"**ERROR:** Path check failed. Please verify the directory paths: {e}")
        return

    # โหลด Object Masks
    objects = []
    for obj_file in object_files:
        try:
            obj_mask = Image.open(os.path.join(OBJECT_DIR, obj_file)).convert("L")
            objects.append(obj_mask)
        except Exception as e:
            print(f"!! Error loading Object Mask {obj_file}: {e}")

    if not objects:
        print("**ERROR:** Could not load any Object Masks.")
        return

    for bg_file in background_files:
        try:
            background_path = os.path.join(BACKGROUND_DIR, bg_file)
            composite_pil = Image.open(background_path).convert("RGB")
            bg_np = np.array(composite_pil, dtype=np.float32)
            bg_width, bg_height, _ = bg_np.shape

            # ใช้ composite_np สำหรับการประมวลผล Math Blending
            composite_np = bg_np.copy()

            for i in range(NUM_OBJECTS_PER_BG):
                random_object_mask = random.choice(objects)

                # สุ่มขนาดและหมุน
                scale_factor = random.uniform(MIN_SCALE_FACTOR, MAX_SCALE_FACTOR)
                new_obj_width = int(bg_width * scale_factor)

                w_percent = (new_obj_width / float(random_object_mask.size[0]))
                new_obj_height = int((float(random_object_mask.size[1]) * float(w_percent)))

                if new_obj_width == 0 or new_obj_height == 0: continue

                resized_mask = random_object_mask.resize((new_obj_width, new_obj_height), Image.Resampling.NEAREST)

                fill_color = 128
                rotated_mask = resized_mask.rotate(
                    random.randint(0, 359),
                    expand=True,
                    resample=Image.Resampling.NEAREST,
                    fillcolor=fill_color
                )

                mask_np = np.array(rotated_mask, dtype=np.float32)
                obj_h, obj_w = mask_np.shape

                # Random Position (x, y)
                max_x = bg_width - obj_w
                max_y = bg_height - obj_h

                if max_x <= 0 or max_y <= 0: continue

                random_x = random.randint(0, max_x)
                random_y = random.randint(0, max_y)

                # --- 1. สร้าง Active Mask ---

                # A. หาพิกเซลที่อยู่ในช่วงของ Object/Shadow
                is_object = np.logical_and(mask_np >= OBJECT_COLOR - ACTIVE_COLOR_TOLERANCE, mask_np <= OBJECT_COLOR + ACTIVE_COLOR_TOLERANCE)
                is_shadow = np.logical_and(mask_np >= SHADOW_COLOR - ACTIVE_COLOR_TOLERANCE, mask_np <= SHADOW_COLOR + ACTIVE_COLOR_TOLERANCE)
                is_active = np.logical_or(is_object, is_shadow)

                # D. สร้าง Alpha Channel (โปร่งใส 0/ทึบ 255)
                alpha_np = np.where(is_active, 255, 0).astype(np.uint8)
                alpha_channel_pil = Image.fromarray(alpha_np, mode='L')

                # --- 2. Math Blending บน Background RGB โดยตรง (Colorize) ---

                # Crop พื้นที่ Background มาเพื่อทำการ Blending
                y1, y2 = random_y, random_y + obj_h
                x1, x2 = random_x, random_x + obj_w
                bg_area_np = composite_np[y1:y2, x1:x2, :].copy()

                blended_area_np = bg_area_np.copy()

                for c in range(3): # Loop R, G, B channels
                    current_channel = bg_area_np[:, :, c]

                    # 1. Calculate Lighten (Object)
                    # out = original + (255 - original) * strength
                    lighten_value = current_channel + (255.0 - current_channel) * LIGHTEN_STRENGTH

                    # 2. Calculate Darken (Shadow)
                    # out = original * (1.0 - strength)
                    darken_value = current_channel * (1.0 - DARKEN_STRENGTH)

                    blended_channel = current_channel.copy()

                    # Apply Lighten for White areas (Object)
                    blended_channel = np.where(is_object, lighten_value, blended_channel)

                    # Apply Darken for Black areas (Shadow)
                    blended_channel = np.where(is_shadow, darken_value, blended_channel)

                    blended_area_np[:, :, c] = blended_channel

                # --- 3. แปะผลลัพธ์ Blend กลับบน Background (ใช้ PIL Paste) ---

                # แปลงผลลัพธ์การ Blend กลับเป็น PIL Image
                blended_object_rgb_pil = Image.fromarray(np.uint8(np.clip(blended_area_np, 0, 255)), mode='RGB')

                # สร้างภาพ RGBA เพื่อให้ paste รู้ว่าควรทำอะไรกับ Alpha Channel
                blended_object_rgba_pil = Image.merge('RGBA', blended_object_rgb_pil.split() + (alpha_channel_pil,))

                # แปะภาพ RGBA ลงบน Background RGB
                composite_pil.paste(blended_object_rgba_pil, (random_x, random_y), mask=blended_object_rgba_pil)

            # บันทึกภาพผลลัพธ์
            output_path = os.path.join(OUTPUT_DIR, f"composite_{bg_file}")
            composite_pil.save(output_path, quality=95)

            print(f"Saved: {output_path}")

        except Exception as e:
            print(f"!! ERROR processing Background {bg_file}: {e}")

print("\nProcessing complete!")

# --- 4. Colab Execution ---

# Run the main function
process_images_colorize_and_blend_increased_strength()
print("-" * 50)
print("Processing finished! Check your output folder in Google Drive. ")
# Out:
# Processing complete!
# --- Starting Colorize and Blend Process (Increased Strength) ---
# Mounted at /content/drive
# /tmp/ipython-input-1283982247.py:132: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   alpha_channel_pil = Image.fromarray(alpha_np, mode='L')
# /tmp/ipython-input-1283982247.py:167: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   blended_object_rgb_pil = Image.fromarray(np.uint8(np.clip(blended_area_np, 0, 255)), mode='RGB')
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0617_bmp.rf.e18cfb57651fe5b30af3eab6025d9774.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0614_bmp.rf.6b85f1f82961a90d8ab0b739334884d5.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0613_bmp.rf.983569995238b90abaa433dd3cfc98dc.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0612_bmp.rf.732d31dba8a8e02b5704c29f167b993b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0611_bmp.rf.f429a39c3ab1662368f0e9455c510c37.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0600_bmp.rf.92babc41130e144ba149d0f69137bb48.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0609_bmp.rf.06ec5861f9599b09ab35d4fccc627ca5.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0599_bmp.rf.e78482a56296252b2856ab32e23328f7.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0605_bmp.rf.d545420cb8365c3941a1e356a9a1a1d8.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0596_bmp.rf.3240b5390bc5d31ef15258065ec42e12.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0593_bmp.rf.04de685120d51318ab96a8a7bf065301.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0591_bmp.rf.94181e2253dc098aa117d4daad9b8e87.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0587_bmp.rf.7b64f76e60b7804e074a88693bc6863e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0586_bmp.rf.a69195aeb26bf3a35708640d91eb2fdd.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0585_bmp.rf.0ed227a9bdb372bfeb972f4c2abf570f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0589_bmp.rf.09459f683bc45d6cf10e8e2b02824d33.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0582_bmp.rf.084da0cfa82404e41bb2a4e49e223780.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0581_bmp.rf.0b518a371f4ecc89f9dda06d37010d5e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0578_bmp.rf.2e14a68d8b42aed87829974193d3cf8e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0575_bmp.rf.a4f3f23f090fc20c1171f76d3fd5dfaf.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0579_bmp.rf.00a3df2a7a8c758f5ef2aa4869858b33.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0574_bmp.rf.5c4a25d08aee9022b7ed19f8796c7959.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0571_bmp.rf.c493cace56155017b9a78759d4692f51.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0569_bmp.rf.c1ac520a0d5f43e856155aef5b272443.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0566_bmp.rf.192e0c58ce6157ed3ab39ca44e4de397.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0567_bmp.rf.459bd8568e78caa60f8dc58cb32fd7a9.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0565_bmp.rf.f86b8866bca3bc74eed4e5931a2d7e78.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0564_bmp.rf.f8bf034d4f546e5017a8e756197d646a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0562_bmp.rf.22363e5568ff98268c0670029f0b0d2b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0563_bmp.rf.054288355f69413755e1ff61fb33c6a0.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0561_bmp.rf.6b50ae9f1f68f60d0394175621717825.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0559_bmp.rf.e3903b8932e0ab33284a9cecc81c115f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0557_bmp.rf.6045f587c1dd2d31f1caf4c00fe94a79.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0555_bmp.rf.2b38138347741c4003530428976f0043.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0550_bmp.rf.dcc0d47c67cc262dd56c0a4958649b3e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0549_bmp.rf.f21b4f25da4b714a1032b6f4fd485aa4.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0548_bmp.rf.0b0f8a5249796d83bcf894a91f0aca70.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0547_bmp.rf.b36728fee6ba1f4dfa1302b87d75c438.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0539_bmp.rf.55f562dd7b3ac8f8fa90a280773af679.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0546_bmp.rf.d26014103d1882ee7efbf5cdba4ed036.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0538_bmp.rf.b6c0a1b8ccb07ef5cc1535e10993dd0b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0536_bmp.rf.24925a5e34d5f1e8739c9916315601ee.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0535_bmp.rf.20e1e2c5a89310778e1f8e9cb3c3fd3a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0532_bmp.rf.b13f8f3a3810a951c2fcde6605d0ecd9.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0531_bmp.rf.6b822df146dd3b517859e5f330868ed1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0530_bmp.rf.1b3fa2192d7c557804850cfa1af4791b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0528_bmp.rf.16ea2f02970554e28eb8f5decbc20b32.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0529_bmp.rf.6b77307f8b35134191d24245af147cbf.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0527_bmp.rf.50be7e17010c14622d393034641d5f2d.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0525_bmp.rf.0688d1f3af3ac29ff319a20ac13dc709.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0524_bmp.rf.548368527d504b59678440fd72e4b842.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0522_bmp.rf.9a1814c8048fbc2c785217892a9809a3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0523_bmp.rf.e474e6d3fb3a072867b8388566a4e6e8.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0521_bmp.rf.103ec0aa026fab5708d97f169e30e727.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0519_bmp.rf.59d0fda9be24e1453e6562aa8524aa36.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0518_bmp.rf.9bfdc0d1a2a0761666dbc764b01be840.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_19_exp2_0517_bmp.rf.cee5ec2f898fef4d970ca96ee3b4bf97.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0513_bmp.rf.61d12a37c136855cfdfbc9befd6070a1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0512_bmp.rf.992667244307a98029851c25aa6580b5.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0511_bmp.rf.b25a6a85b3ff0048e8a0615a2fba35fa.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0510_bmp.rf.8a712cf9cbed40abff29d40fa5edfe5a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0508_bmp.rf.c0f2a441a8f737ddcf9b71f0a61c3261.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0507_bmp.rf.08d733c90e9f24fdafaea62d9039105e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0506_bmp.rf.04fcb233fdd58ac0fcb7813e11a380bf.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0501_bmp.rf.f3d9aa70a3163671c0c57aba4f99b83a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0499_bmp.rf.efc51c8b391b23e201c9c0fe585efd1f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0497_bmp.rf.55d0fe29493b6da1e44c68a1cbe6d1ab.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0496_bmp.rf.72664fc960c9ab943fe3731ce74feba3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0494_bmp.rf.65b90492c811fadfa1047be9c0bedaa2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0493_bmp.rf.f544c2b8ddd73bb0edf2bf5250014d5f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0492_bmp.rf.58e57aa8c3e1985213665b75cc2bdd59.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0491_bmp.rf.5def4b9c44613f8977acd19305606d39.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0490_bmp.rf.9ee76686cce461e389f9e8b9e27f8f75.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0488_bmp.rf.08d014c9c95b67ef7e845d23df6cfc21.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0486_bmp.rf.f3ac0315628bbfdda53ace554b54de90.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0485_bmp.rf.ad7233a7bafdb3ee2af5d51309bf9702.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0480_bmp.rf.76c4b022981cc465672f65daf088ff57.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0484_bmp.rf.69177a130cb751b7b2e38d9e985232c5.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0476_bmp.rf.2d36dee35ed3e692700b35f903517c30.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0475_bmp.rf.bfdeb629147b0b624cfd7cd0c472cabf.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0474_bmp.rf.996311ed0a71ca711f1755f3ea021eb5.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0473_bmp.rf.710e525b5d35094728a39724dd4a4ec0.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0470_bmp.rf.817e7b36ded701a14dd73e978f780e92.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0472_bmp.rf.eb30c9839b1cb6335a2933ac25b31316.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0466_bmp.rf.90f816acc70cb78557cfd73cc450aa1f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0465_bmp.rf.fbc50141376fb011968c3d23d6ae5da9.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0464_bmp.rf.06d4353f54069c9fba037160d54e2d3d.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0459_bmp.rf.027d4979549ccdf6115bd473f002f402.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0457_bmp.rf.224c7763e874638bc098687d907af7a0.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0451_bmp.rf.1026e239cfe4f17ba9095033265b2ae4.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0449_bmp.rf.44a28979e594be4e11d809ac9dc29d46.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0448_bmp.rf.3bca092b8c9175806bdde5ae4d706a3d.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0447_bmp.rf.bc5cedfd1bf9b63376d5e34f4ef09545.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0443_bmp.rf.3f738c2af090459977634ec26fe55224.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0439_bmp.rf.59272868554944e4f203573790cf7402.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0437_bmp.rf.3bb37406c10328b437fa2791b516c8a8.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0436_bmp.rf.496210c2b0e017ee060318a762108c84.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0435_bmp.rf.2cffdf9a2f2d7808dcab9c6f4d92aeb2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0433_bmp.rf.85cbaea2fe97cb176a24ce50a36a4d08.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0428_bmp.rf.de84528d80b30febae4a7d4c7e0b7c23.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0426_bmp.rf.628f616ad05a54c4042999183c22a0cb.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0422_bmp.rf.156f049185e73e23e1fa858441f86e34.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0418_bmp.rf.f8f27109a9e51778be95aed3c610cb05.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0421_bmp.rf.7bce80218926f94c9b2dc1f24d8810fc.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0417_bmp.rf.ff69b01e1f23be220a6da73584e102ca.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0416_bmp.rf.10ade45bfe07559ca4fe55cecbf05a57.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0415_bmp.rf.cefb27c5c19c07e71c9f409aba6f26b1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0414_bmp.rf.625340358fa88364df58a187bc40d75f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0413_bmp.rf.469f0078c29932d1c17f79761859437f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0411_bmp.rf.92ccd581f75be81aa74f935602167fad.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_18_exp2_0410_bmp.rf.ba6f9db17812235b69322a1583a78bc6.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0405_bmp.rf.c61b735f74ac9850b57f41526c023a66.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0404_bmp.rf.59bfc27191b8c50a0783dd4a5ae56ffb.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0402_bmp.rf.24992580b4aa6943effc94b3e4a44002.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0401_bmp.rf.38002f86bb4eb122cba9691f59057830.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0400_bmp.rf.900b6177b420654c27b793afd439d7bf.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0399_bmp.rf.2d747aa89b03f1513c53da8b40ac018d.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0398_bmp.rf.7be95b675848edeac00fd50a64047f17.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0396_bmp.rf.3631e77ead72290d1ea651a2e2ee688d.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0395_bmp.rf.9209ac75d26c1ba9848b05d9195bb515.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0390_bmp.rf.db4275501d38160bab0751821ae95725.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0393_bmp.rf.d1f6d8d782dea689ce39a98f4adb9c0a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0388_bmp.rf.37738d7c2ef925e10be50f2fbe977d80.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0387_bmp.rf.d12e90e02ae7908fce10a0d76e160711.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0385_bmp.rf.cc87a37c9284574a652250bc3c39d524.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0380_bmp.rf.33a21fd8ce0ed6c3dd96ff1bb7356e0b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0379_bmp.rf.cd68d5c3e4077d8e8dd6e99a691d71df.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0378_bmp.rf.27057564f6f056d3da311c1d91a359c9.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0375_bmp.rf.a42a6fdfdf1c329e2c8b92b7353ab87f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0374_bmp.rf.2001348ad75dd11be9089d873d22d5c1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0369_bmp.rf.02fc79ba72a1a1b7a6249bcc37141353.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0367_bmp.rf.26e2a609572a4d5722c5aa7271ed434d.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0366_bmp.rf.3235f83a4d932785cc4625b442e2ba71.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0364_bmp.rf.f37957421fbdf0290bb3b15939a87f29.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0363_bmp.rf.e12869bc2253a90b2534804b806de9dd.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0359_bmp.rf.47cbc9491c564eb00aec9206e7f69c2b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0362_bmp.rf.515c650e7cd967be0820764eb5bff4e2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0358_bmp.rf.153446dba0eb11eb74b8fb4af94c4e0c.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0361_bmp.rf.bb87af5425d04c30d1ee3ff0f0820525.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0357_bmp.rf.a3b74f67caf4c42760446b3cdeeb5bcd.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0356_bmp.rf.af6ead3491587849bf496e7db6784cdb.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0355_bmp.rf.2b7bb1c5642304581c7d999a1ef06951.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0352_bmp.rf.d7c643be268bb23b6733bbf6c747141e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0351_bmp.rf.32b458dd3d13096a551f2722cad98ce6.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0350_bmp.rf.eefa78fd6deda90813dd2ad9b79211a7.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0347_bmp.rf.dec28f28c6289c63f55f527272462e0a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0346_bmp.rf.d04e48fd71b9e7ba7caf32e861cec816.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0345_bmp.rf.5710e201c0b8d3c36d30dd94bfbbac84.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0344_bmp.rf.11862932e52e518a903a895f9acdebe2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0343_bmp.rf.1256335a5aa9298e2f2545dc0821edfb.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0339_bmp.rf.ab88fef1bb0c865976238cec43d0f683.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0333_bmp.rf.c46a0befeaa6af2fbd65574efc2dba58.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0332_bmp.rf.cf75c4abeced0142114bec9419e74120.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0331_bmp.rf.c10e94ce573f81f0dbd26042cbe74fb0.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0329_bmp.rf.2dab45a03801ca4beb582fb076534228.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0328_bmp.rf.6e96fa286745ae5312a9aa642dd42a58.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0327_bmp.rf.f6b194c68b0b95fc715c0ad44dfed685.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0321_bmp.rf.125206006d08bddd242ca817ab8ed744.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0318_bmp.rf.662e352834af02779e58116986ee3907.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0316_bmp.rf.ced848c505bed95b4171e1cd6de0fe89.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0313_bmp.rf.45079cf82d37bc03e670279c4aaef5d2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0311_bmp.rf.b7b711b4b63cc2f928d9dff54335c54f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0307_bmp.rf.ad830eb42d4fbc5cfe6f37ed922e1348.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0305_bmp.rf.247d923d80cb6ad4bb0aaecf4b39e3dd.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0302_bmp.rf.5da66dd20bf334fd28ed14da43e0777c.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_11_16_exp2_0301_bmp.rf.3bc64d31832741570da6ecc2b7639f6a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0295_bmp.rf.2e5903e67f4ab52d4960e56d7ca97fc9.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0294_bmp.rf.0731befd9803dfec3c52f1fbf3913793.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0293_bmp.rf.e1a61042b4649c7a3de0c296c887e7cc.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0291_bmp.rf.1e326a1482c5f2a7612378b4ace37cb1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0290_bmp.rf.48a9ff722400e846946fe8b7d043eb6b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0289_bmp.rf.7d257911c3bb1ac7990fb2d04aff8cc2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0284_bmp.rf.40b5785c6bac09ee846222911a2276c5.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0283_bmp.rf.79c0faadc2b5bd4e34d8dfd72632b623.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0282_bmp.rf.d068d4775a98758bb22201865d9dedfb.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0281_bmp.rf.e6872d5d163e60134bd52bfbb96a62d0.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0280_bmp.rf.fd1197f5fce3263616e49123c9d21ab1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0277_bmp.rf.a9ec4175437b8f692f1a0973daacce63.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0274_bmp.rf.b4df9426e6c289f1399ea8a65bdcf6d0.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0273_bmp.rf.533ad0dea13f743511e9b9eb2ffc95f7.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0272_bmp.rf.941a6f16c35218ecd9207c16adfaa836.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0270_bmp.rf.aee17471d12916a804e3dc03b9574275.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0269_bmp.rf.0fe94d7742d8c446d24d38719cbc50e0.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0268_bmp.rf.77b9cd9d747cb223b77d3bddb68b2207.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0266_bmp.rf.e1672643c8e634c5c57c1b63036afa18.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0265_bmp.rf.ba1963427e381ca848d1bb6dc9fad57f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0263_bmp.rf.96e658cac8a55dca11162a005f02dcc8.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0262_bmp.rf.91731d4c61f8207f2a9d67271440d3a3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0260_bmp.rf.e2204036ca3e7524abd98541dd063d4e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0259_bmp.rf.d3f3ccf4d36ee80a2ac7e0adc4152661.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0258_bmp.rf.a040c6d1d37089798ac4b0131c8d4e97.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0257_bmp.rf.a06167b9924b01143595032e30e6aded.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0256_bmp.rf.3339d380c78b2c261f0a7e114cf42ea8.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0255_bmp.rf.560302a947cc174702a1d3e7123da4aa.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0254_bmp.rf.b1c240d3c1b55b482565eb60e74b46e0.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0253_bmp.rf.cb010678676a3e003c5cdab4293a9e48.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0252_bmp.rf.b70b1e7c6630e565431ef318bcb7f14a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0251_bmp.rf.fe583f4d7aefa876125fb01f9275e9dd.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0250_bmp.rf.6c793032bc5282c6e73ec148021abeaa.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0248_bmp.rf.ec5827b6629816a3b10f262adb68f629.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0246_bmp.rf.d7c39aeb8b3542cdc0cca2ee8fcbfabb.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0245_bmp.rf.393aedb12bbd3b8ee8d3b613de4e5c6e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0244_bmp.rf.09f34b508e179184b607ce8dd6cb0cca.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0243_bmp.rf.0793da4b9d2ec6aed42137d66980b1ca.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0240_bmp.rf.ce40b4a45aa1c7a40e3c00eaebd1b871.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0239_bmp.rf.96667e9f5dee3ac8744d21351ac0e5d4.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0235_bmp.rf.a9c1f834d537ab80f76c4146f60b30ca.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0234_bmp.rf.e197dab2fa35ca9a48ec0c60da6b5562.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0233_bmp.rf.3e698292ffe764edfdd096ffffdb75e4.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0232_bmp.rf.b92ecb2287630670c2a092e7940a2853.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0230_bmp.rf.dddd14d5b80772feaa3d28218b7c247a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0229_bmp.rf.b61884b0befc58cef3e8bff42b829143.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0228_bmp.rf.a5d1dd9dd577bf0940b6b30ebe5c75b3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0227_bmp.rf.60eaa7244424b733c6d3cccea13b9164.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0224_bmp.rf.0513bc2435a0aaba050c4a2a725c6403.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0222_bmp.rf.9b9fd06f9dbf7ef871f70839d2bcbc37.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0219_bmp.rf.efa890d95044bcabd1499c5ada371eb3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0218_bmp.rf.89173c0cdef180f640b9d015f4b1a7f4.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0217_bmp.rf.2da86c39a8ea160677501f10cf126b2d.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0216_bmp.rf.bb9ac8fbab924ca2bb444f4907851b37.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0215_bmp.rf.1c5ad9ff7991eb12c09a82b4a2e9a3c6.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0212_bmp.rf.3b5a88f46945976b89fa9078851d24f2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0211_bmp.rf.088844cac02b3788ccb42e4d4286f48a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0207_bmp.rf.d7d425047ae646c2a98d6c57ab028820.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0208_bmp.rf.9cb974d049738bc7381fc0a658bb2c3a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0206_bmp.rf.fb38259a7191300031a416d3b296accb.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0205_bmp.rf.542880e71c649fdbe373f96c94413218.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_30_exp1_0204_bmp.rf.b1df8e9d94e5952067edc864abdc52d6.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0203_bmp.rf.1f21e6971fa5a47f8b5bcb5f8d759758.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0202_bmp.rf.302dd49955bd094bc9eb646ec404e524.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0201_bmp.rf.b923ee4f569f7db85ba6a18061383d14.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0199_bmp.rf.103805374c69bfecc9271e1d628865aa.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0197_bmp.rf.f88cf4885951bb38747f19f8d425e0f6.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0195_bmp.rf.579278db295a38a083b1d5c3db04a885.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0194_bmp.rf.758db76002d004bef4f146538db1671e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0193_bmp.rf.75d48b3a64e2fc118842975633c7632c.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0192_bmp.rf.edba7ca6882ffc6e25ac180f4a6fe18f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0190_bmp.rf.764a3331d42d5f5a2e554a7ba0f58f95.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0188_bmp.rf.1fe8a9088623bfc139da6bd69a04a12f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0186_bmp.rf.608ddbf61507190416f146b784c41e12.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0185_bmp.rf.97fdbbf5758c9b168bd4e75efbf2e363.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0184_bmp.rf.95b61ee9cbcfe21524823c7db13df560.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0183_bmp.rf.1fe4250d12bfb5b1f859b383d14c8cf5.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0182_bmp.rf.0a8879e82cbe19a2018c5cda6fe91977.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0181_bmp.rf.3d72eb16e1abb9e217467e27e0ac41b6.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0180_bmp.rf.0270595528f6fdd519edb068124a02f3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0178_bmp.rf.a5fdb10c9eba3821cec27498ace9d3df.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0177_bmp.rf.62ababfb1feb31bff2f1479b8644758f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0175_bmp.rf.897a23319c4ace08c540288337649d01.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0174_bmp.rf.d8a3edeae5465b5b8feb300919d3403e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0172_bmp.rf.41799d1cbdf0d4f1e49cc80a3b11ba3a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0171_bmp.rf.259f7a3fcb50e8f977a984f7657f608e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0167_bmp.rf.4aa3c67815a598e41e03fba80b9545c2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0166_bmp.rf.1066f1852f4a65494653e0cad01ae13f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0161_bmp.rf.b21f38889b12ea6f4261eeacc26a28fd.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0160_bmp.rf.d4a2badc5486944d8ad3ca291cb80e26.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0157_bmp.rf.ced9450a0f26b774008be20538b14226.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0155_bmp.rf.78d1f493f879b9e690d3c424acde101f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0154_bmp.rf.02e0a3d6fa65e78b2cfb3ab410b1c565.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0147_bmp.rf.e41b5f50cbc4b5f07c5177c9472df4cf.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0146_bmp.rf.40ddafa92e90fe205f1f872f14470998.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0139_bmp.rf.6afe75f9f9ab4cef4b6c811546d84738.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0137_bmp.rf.4f56e8196ffc49b0d9372b4dfeb1305a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0132_bmp.rf.9ae7ec696ed61d16e8b4db0ba2b28262.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0130_bmp.rf.2ca63496a2cfb305bab7ad78269cd840.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0127_bmp.rf.a0d885af0061cd41c2ac303879702309.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0126_bmp.rf.5be9ad293c03bcfaa9569ecbc76129c1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0125_bmp.rf.df301e6c4f87a03a07a663085c439e1c.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0124_bmp.rf.dcf16ed84743fb611889c80c602551be.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0123_bmp.rf.3bb6b3cca64e515008e9716bc8057ab2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0122_bmp.rf.48e0e9569bd396ff7c9ee3a65c5a67c3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0120_bmp.rf.169be5d6ee76f25fe8f561d22cadcb11.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0114_bmp.rf.33d592f5547a2a11593ae3897e59e408.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0112_bmp.rf.2c09e6c944bacad277e1c5d44d270111.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0109_bmp.rf.254049d90aae59a1e12ad0608cd93b5b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0108_bmp.rf.1596e5e366e77eb3d2280617c49badd2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0106_bmp.rf.095213cdd1747fc570f8bb7d8b0d04a3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0105_bmp.rf.6f52a08e8b24a1414acb30e29bb79cd3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0103_bmp.rf.a6d6ac4db068f9268206fefe1bca2b4c.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0101_bmp.rf.8c72a7165601c61c3fc770747175808e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0100_bmp.rf.86ef9dbda1c3c88e3bf3900a49757c0b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0099_bmp.rf.ae584062bffa1f744492fd4e32e6d879.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0097_bmp.rf.a4e83f62340afd3d39eaeaa3984d3cc7.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0096_bmp.rf.e9ff98d71d65c0ce5fcf9c5332283cfe.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0095_bmp.rf.6b59ff76ea97745a65531d67336d1ba3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0094_bmp.rf.66d40b327a6c8eadbf521604b7bd593f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0092_bmp.rf.0a78a4692c4ed32f6273cda82a5d37af.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0091_bmp.rf.7ee3221422a0fe5e11c22905bde33739.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0085_bmp.rf.13d35c70d6c167d7f5aaae7fb43943d1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0089_bmp.rf.c964bd93be9e76fe7df815ca14648e68.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0084_bmp.rf.0161ab46f1f695bcdb4e934c4040558a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_29_exp1_0082_bmp.rf.ff3276504b3e55b19831b137f5cdf9e3.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0081_bmp.rf.99f9c68e898b87e477e9e40fa95bed6c.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0079_bmp.rf.607039502f69140d1501176672b5ddeb.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0078_bmp.rf.7cbd1470634136990f1142a650139e6a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0075_bmp.rf.21e515f8126f55c8fa9e9b77441bd3ea.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0074_bmp.rf.b42ce168deb9967f70b6f32cb78c338b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0073_bmp.rf.b94b506d679cbf4c2191da9841a27ad1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0072_bmp.rf.105da6de4cd8ebfae47db5e72073efb7.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0068_bmp.rf.547744eeef184d88f97822a24b8a8f42.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0066_bmp.rf.89fff9ff7aec9e4fa96facc5d2053e37.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0062_bmp.rf.110abb38747a7079f9d08a95b812a4ab.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0061_bmp.rf.9366d1345a44d386f4a225442bc82864.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0058_bmp.rf.6128ccd6e8de196a3d2369ba138bade8.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0056_bmp.rf.58b62f0136d2802b1d892d65bb2e1124.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0055_bmp.rf.ebbc1aec32525151cc2d5b7ce47eb2a7.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0054_bmp.rf.7af390fc1d881152d718c8c10bab730a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0051_bmp.rf.6fce041a971209fd802f23548e22be9f.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0050_bmp.rf.8dd17223cbcbe68356b128621ac141c1.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0046_bmp.rf.7e645ce13650b98df2ac34b699c74452.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0044_bmp.rf.afd6f00a896838a3973679eb92d6d2be.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0040_bmp.rf.64a53091c986665eecd8fd1085c1179b.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0039_bmp.rf.e3ad5fc9959d2c1bc72c599960238b81.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0038_bmp.rf.ab6daaacf04d8573d02b1dc189d261f2.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0033_bmp.rf.0cc86a94a84489b112a717c57264c5a8.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0029_bmp.rf.b452e583c8e8489b48e1ed8a33ea9242.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0027_bmp.rf.cd469f3df600b7eadc50d3ae77a9daf9.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0025_bmp.rf.1818276744c4b8d6115a33427d323812.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0024_bmp.rf.27c8d57dba838a564181318b96830b44.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0022_bmp.rf.c66c709431ba8b57801503f5d8d05539.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0021_bmp.rf.3998f118e539d21a2d3ea27da844d763.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0019_bmp.rf.c3ee06f0facf7b74140e4b32805059bf.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0018_bmp.rf.4df10526598a020e9ad9879eececa041.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0016_bmp.rf.0d8827967b441f07aee1958d7087fc80.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0011_bmp.rf.f9e51f501f5f899c3d819b15609b722e.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0009_bmp.rf.9da925e568a58306e4451997bf2edc6a.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0006_bmp.rf.881aa290b8c1c18f5390ad908ae9e341.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0004_bmp.rf.04ba0495b8a26c0d387604053c5ea904.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0003_bmp.rf.635f1d204a6cf0fca1370da11ec5120d.jpg
# Saved: /content/drive/MyDrive/SeniorProj/output/composite_2021_09_28_exp1_0002_bmp.rf.def27e075ace02ba7c4a30b3954cb8bf.jpg
# --------------------------------------------------
# Processing finished! Check your output folder in Google Drive.
